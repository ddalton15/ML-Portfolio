# %%
# %pip install 'smolagents[litellm]'
# Out:
# Collecting smolagents[litellm]
#   Downloading smolagents-1.24.0-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.7/155.7 kB 1.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: jinja2>=3.1.4 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from smolagents[litellm]) (3.1.6)
# Requirement already satisfied: python-dotenv in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from smolagents[litellm]) (1.1.1)
# Requirement already satisfied: requests>=2.32.3 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from smolagents[litellm]) (2.32.5)
# Requirement already satisfied: pillow>=10.0.1 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from smolagents[litellm]) (12.0.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.31.2 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from smolagents[litellm]) (0.36.0)
# Collecting rich>=13.9.4
#   Using cached rich-14.3.2-py3-none-any.whl (309 kB)
# Collecting litellm>=1.60.2
#   Downloading litellm-1.81.13-py3-none-any.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 50.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: packaging>=20.9 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[litellm]) (25.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[litellm]) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[litellm]) (1.2.0)
# Requirement already satisfied: filelock in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[litellm]) (3.20.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[litellm]) (6.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[litellm]) (4.15.0)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[litellm]) (4.67.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from jinja2>=3.1.4->smolagents[litellm]) (3.0.3)
# Requirement already satisfied: aiohttp>=3.10 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from litellm>=1.60.2->smolagents[litellm]) (3.13.2)
# Requirement already satisfied: tiktoken>=0.7.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from litellm>=1.60.2->smolagents[litellm]) (0.12.0)
# Requirement already satisfied: tokenizers in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from litellm>=1.60.2->smolagents[litellm]) (0.22.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.23.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from litellm>=1.60.2->smolagents[litellm]) (4.25.1)
# Requirement already satisfied: httpx>=0.23.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from litellm>=1.60.2->smolagents[litellm]) (0.28.1)
# Collecting importlib-metadata>=6.8.0
#   Downloading importlib_metadata-8.7.1-py3-none-any.whl (27 kB)
# Collecting openai>=2.8.0
#   Downloading openai-2.21.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 47.0 MB/s eta 0:00:00
# Requirement already satisfied: click in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from litellm>=1.60.2->smolagents[litellm]) (8.3.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from litellm>=1.60.2->smolagents[litellm]) (2.12.3)
# Collecting fastuuid>=0.13.0
#   Downloading fastuuid-0.14.0-cp310-cp310-macosx_11_0_arm64.whl (254 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.5/254.5 kB 28.8 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from requests>=2.32.3->smolagents[litellm]) (2025.10.5)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from requests>=2.32.3->smolagents[litellm]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from requests>=2.32.3->smolagents[litellm]) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from requests>=2.32.3->smolagents[litellm]) (3.4.4)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from rich>=13.9.4->smolagents[litellm]) (2.19.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm]) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm]) (1.8.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm]) (4.0.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm]) (6.7.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm]) (2.6.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm]) (1.22.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm]) (0.4.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm]) (25.4.0)
# Requirement already satisfied: anyio in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from httpx>=0.23.0->litellm>=1.60.2->smolagents[litellm]) (4.11.0)
# Requirement already satisfied: httpcore==1.* in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from httpx>=0.23.0->litellm>=1.60.2->smolagents[litellm]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.23.0->litellm>=1.60.2->smolagents[litellm]) (0.16.0)
# Collecting zipp>=3.20
#   Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: referencing>=0.28.4 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.23.0->litellm>=1.60.2->smolagents[litellm]) (0.37.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.23.0->litellm>=1.60.2->smolagents[litellm]) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.23.0->litellm>=1.60.2->smolagents[litellm]) (0.27.1)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from openai>=2.8.0->litellm>=1.60.2->smolagents[litellm]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from openai>=2.8.0->litellm>=1.60.2->smolagents[litellm]) (0.11.1)
# Requirement already satisfied: sniffio in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from openai>=2.8.0->litellm>=1.60.2->smolagents[litellm]) (1.3.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.5.0->litellm>=1.60.2->smolagents[litellm]) (0.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.5.0->litellm>=1.60.2->smolagents[litellm]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.5.0->litellm>=1.60.2->smolagents[litellm]) (2.41.4)
# Requirement already satisfied: regex>=2022.1.18 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from tiktoken>=0.7.0->litellm>=1.60.2->smolagents[litellm]) (2025.9.18)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from anyio->httpx>=0.23.0->litellm>=1.60.2->smolagents[litellm]) (1.3.0)
# Installing collected packages: zipp, mdurl, fastuuid, markdown-it-py, importlib-metadata, rich, smolagents, openai, litellm
#   Attempting uninstall: openai
#     Found existing installation: openai 2.5.0
#     Uninstalling openai-2.5.0:
#       Successfully uninstalled openai-2.5.0
# Successfully installed fastuuid-0.14.0 importlib-metadata-8.7.1 litellm-1.81.13 markdown-it-py-4.0.0 mdurl-0.1.2 openai-2.21.0 rich-14.3.2 smolagents-1.24.0 zipp-3.23.0
#
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from smolagents import LiteLLMModel

model = LiteLLMModel(
    model_id="ollama_chat/qwen2:7b",  # Or try other Ollama-supported models
    api_base="http://127.0.0.1:11434",  # Default Ollama local server
    num_ctx=8192,
)
