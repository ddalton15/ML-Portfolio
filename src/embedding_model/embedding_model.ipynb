# %%
# !pip install sentence-transformers datasets torch
# Out:
# Requirement already satisfied: sentence-transformers in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (5.2.0)
# Requirement already satisfied: datasets in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (4.4.1)
# Requirement already satisfied: torch in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (2.9.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from sentence-transformers) (4.57.3)
# Requirement already satisfied: scipy in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: scikit-learn in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from datasets) (6.0.3)
# Requirement already satisfied: fsspec[http]<=2025.10.0,>=2023.1.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from datasets) (2025.10.0)
# Requirement already satisfied: httpx<1.0.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from datasets) (0.27.2)
# Requirement already satisfied: numpy>=1.17 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from datasets) (2.2.6)
# Requirement already satisfied: filelock in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from datasets) (3.20.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from datasets) (22.0.0)
# Requirement already satisfied: pandas in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: packaging in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from datasets) (25.0)
# Requirement already satisfied: requests>=2.32.2 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from datasets) (2.32.5)
# Requirement already satisfied: xxhash in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from datasets) (0.70.18)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from torch) (1.14.0)
# Requirement already satisfied: jinja2 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: networkx>=2.5.1 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: httpcore==1.* in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: certifi in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (2025.10.5)
# Requirement already satisfied: sniffio in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: anyio in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (4.11.0)
# Requirement already satisfied: idna in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.9.18)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: six>=1.5 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages (from anyio->httpx<1.0.0->datasets) (1.3.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import torch
from sentence_transformers import (
    SentenceTransformer,
    InputExample,
    losses,
    models,
    util,
)
from torch.utils.data import DataLoader
from datasets import load_dataset

if torch.backends.mps.is_available():
    device = "mps"
    print("✅ Apple GPU detected. Using 'mps' backend.")
elif torch.cuda.is_available():
    device = "cuda"
    print("✅ NVIDIA GPU detected. Using 'cuda' backend.")
else:
    device = "cpu"
    print("⚠️ No GPU detected. Using 'cpu' (Training will be slow).")

BASE_MODEL_NAME = "distilbert-base-uncased"
OUTPUT_PATH = "output/my-google-qa-model-mps"

BATCH_SIZE = 32
NUM_EPOCHS = 1
NUM_SAMPLES = 10000
# Out:
# ✅ Apple GPU detected. Using 'mps' backend.

# %%
from tqdm.auto import tqdm  # This adds a progress bar so you know it's working

# Configuration
NUM_SAMPLES = 10000  # Keep this small for testing
BATCH_SIZE = 32

print("Initializing streaming connection...")

dataset = load_dataset("sentence-transformers/gooaq", split="train", streaming=True)

dataset_head = dataset.take(NUM_SAMPLES)

print(f"Streaming first {NUM_SAMPLES} rows...")

train_examples = []

for row in tqdm(dataset_head, total=NUM_SAMPLES, desc="Processing Data"):
    query = row["question"]
    context = row["answer"]

    if isinstance(query, str) and isinstance(context, str):
        train_examples.append(InputExample(texts=[query, context]))

print(f"Successfully created {len(train_examples)} training examples.")

train_dataloader = DataLoader(train_examples, shuffle=True, batch_size=BATCH_SIZE)
# Out:
# Initializing streaming connection...
# Streaming first 10000 rows...
# Processing Data:   0%|          | 0/10000 [00:00<?, ?it/s]
# Successfully created 10000 training examples.

# %%
import logging

# 1. Turn on detailed logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger("transformers")
logger.setLevel(logging.INFO)

# 2. Test connection to Hugging Face
import requests
print("Testing connection to huggingface.co...")
try:
    response = requests.get("https://huggingface.co", timeout=5)
    print(f"✅ Connection successful (Status: {response.status_code})")
except Exception as e:
    print(f"❌ Connection FAILED: {e}")
    print("STOP HERE: You have a firewall or internet issue.")

# 3. Try downloading with 'resume_download' enabled
if 'response' in locals() and response.status_code == 200:
    print("\nAttempting download with resume support...")
    from transformers import AutoModel
    
    # force_download=True cleans up corrupted cache
    model = AutoModel.from_pretrained(
        BASE_MODEL_NAME, 
        force_download=True, 
        resume_download=True
    )
    print("✅ Download Success!")
# Out:
# Testing connection to huggingface.co...
# ✅ Connection successful (Status: 200)
#
# Attempting download with resume support...
# /Users/dalt353/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 24
#      21 from transformers import AutoModel
#      23 # force_download=True cleans up corrupted cache
# ---> 24 model = AutoModel.from_pretrained(
#      25     BASE_MODEL_NAME,
#      26     force_download=True,
#      27     resume_download=True
#      28 )
#      29 print("✅ Download Success!")
#
# File ~/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:508, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     505 if commit_hash is None:
#     506     if not isinstance(config, PretrainedConfig):
#     507         # We make a call to the config file first (which may be absent) to get the commit hash as soon as possible
# --> 508         resolved_config_file = cached_file(
#     509             pretrained_model_name_or_path,
#     510             CONFIG_NAME,
#     511             _raise_exceptions_for_gated_repo=False,
#     512             _raise_exceptions_for_missing_entries=False,
#     513             _raise_exceptions_for_connection_errors=False,
#     514             **hub_kwargs,
#     515         )
#     516         commit_hash = extract_commit_hash(resolved_config_file, commit_hash)
#     517     else:
#
# File ~/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/transformers/utils/hub.py:322, in cached_file(path_or_repo_id, filename, **kwargs)
#     264 def cached_file(
#     265     path_or_repo_id: Union[str, os.PathLike],
#     266     filename: str,
#     267     **kwargs,
#     268 ) -> Optional[str]:
#     269     """
#     270     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     271
#    (...)
#     320     ```
#     321     """
# --> 322     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     323     file = file[0] if file is not None else file
#     324     return file
#
# File ~/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/transformers/utils/hub.py:479, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     476 try:
#     477     if len(full_filenames) == 1:
#     478         # This is slightly better for only 1 file
# --> 479         hf_hub_download(
#     480             path_or_repo_id,
#     481             filenames[0],
#     482             subfolder=None if len(subfolder) == 0 else subfolder,
#     483             repo_type=repo_type,
#     484             revision=revision,
#     485             cache_dir=cache_dir,
#     486             user_agent=user_agent,
#     487             force_download=force_download,
#     488             proxies=proxies,
#     489             resume_download=resume_download,
#     490             token=token,
#     491             local_files_only=local_files_only,
#     492         )
#     493     else:
#     494         snapshot_download(
#     495             path_or_repo_id,
#     496             allow_patterns=full_filenames,
#    (...)
#     505             local_files_only=local_files_only,
#     506         )
#
# File ~/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/huggingface_hub/file_download.py:1007, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     987     return _hf_hub_download_to_local_dir(
#     988         # Destination
#     989         local_dir=local_dir,
#    (...)
#    1004         local_files_only=local_files_only,
#    1005     )
#    1006 else:
# -> 1007     return _hf_hub_download_to_cache_dir(
#    1008         # Destination
#    1009         cache_dir=cache_dir,
#    1010         # File info
#    1011         repo_id=repo_id,
#    1012         filename=filename,
#    1013         repo_type=repo_type,
#    1014         revision=revision,
#    1015         # HTTP info
#    1016         endpoint=endpoint,
#    1017         etag_timeout=etag_timeout,
#    1018         headers=hf_headers,
#    1019         proxies=proxies,
#    1020         token=token,
#    1021         # Additional options
#    1022         local_files_only=local_files_only,
#    1023         force_download=force_download,
#    1024     )
#
# File ~/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/huggingface_hub/file_download.py:1168, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1165 # Local file doesn't exist or etag isn't a match => retrieve file from remote (or cache)
#    1167 with WeakFileLock(lock_path):
# -> 1168     _download_to_tmp_and_move(
#    1169         incomplete_path=Path(blob_path + ".incomplete"),
#    1170         destination_path=Path(blob_path),
#    1171         url_to_download=url_to_download,
#    1172         proxies=proxies,
#    1173         headers=headers,
#    1174         expected_size=expected_size,
#    1175         filename=filename,
#    1176         force_download=force_download,
#    1177         etag=etag,
#    1178         xet_file_data=xet_file_data,
#    1179     )
#    1180     if not os.path.exists(pointer_path):
#    1181         _create_symlink(blob_path, pointer_path, new_blob=True)
#
# File ~/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/huggingface_hub/file_download.py:1735, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download, etag, xet_file_data)
#    1728         if xet_file_data is not None and not constants.HF_HUB_DISABLE_XET:
#    1729             logger.warning(
#    1730                 "Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. "
#    1731                 "Falling back to regular HTTP download. "
#    1732                 "For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`"
#    1733             )
# -> 1735         http_get(
#    1736             url_to_download,
#    1737             f,
#    1738             proxies=proxies,
#    1739             resume_size=resume_size,
#    1740             headers=headers,
#    1741             expected_size=expected_size,
#    1742         )
#    1744 logger.info(f"Download complete. Moving file to {destination_path}")
#    1745 _chmod_and_move(incomplete_path, destination_path)
#
# File ~/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/huggingface_hub/file_download.py:448, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     441     displayed_filename = f"(…){displayed_filename[-40:]}"
#     443 consistency_error_message = (
#     444     f"Consistency check failed: file should be of size {expected_size} but has size"
#     445     f" {{actual_size}} ({displayed_filename}).\nThis is usually due to network issues while downloading the file."
#     446     " Please retry with `force_download=True`."
#     447 )
# --> 448 progress_cm = _get_progress_bar_context(
#     449     desc=displayed_filename,
#     450     log_level=logger.getEffectiveLevel(),
#     451     total=total,
#     452     initial=resume_size,
#     453     name="huggingface_hub.http_get",
#     454     _tqdm_bar=_tqdm_bar,
#     455 )
#     457 with progress_cm as progress:
#     458     if hf_transfer and total is not None and total > 5 * constants.DOWNLOAD_CHUNK_SIZE:
#
# File ~/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/huggingface_hub/utils/tqdm.py:299, in _get_progress_bar_context(desc, log_level, total, initial, unit, unit_scale, name, _tqdm_bar)
#     294     return nullcontext(_tqdm_bar)
#     295     # ^ `contextlib.nullcontext` mimics a context manager that does nothing
#     296     #   Makes it easier to use the same code path for both cases but in the later
#     297     #   case, the progress bar is not closed when exiting the context manager.
# --> 299 return tqdm(
#     300     unit=unit,
#     301     unit_scale=unit_scale,
#     302     total=total,
#     303     initial=initial,
#     304     desc=desc,
#     305     disable=is_tqdm_disabled(log_level=log_level),
#     306     name=name,
#     307 )
#
# File ~/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/tqdm/std.py:665, in tqdm.__new__(cls, *_, **__)
#     663 def __new__(cls, *_, **__):
#     664     instance = object.__new__(cls)
# --> 665     with cls.get_lock():  # also constructs lock if non-existent
#     666         cls._instances.add(instance)
#     667         # create monitoring thread
#
# File ~/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/tqdm/std.py:111, in TqdmDefaultWriteLock.__enter__(self)
#     110 def __enter__(self):
# --> 111     self.acquire()
#
# File ~/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/tqdm/std.py:104, in TqdmDefaultWriteLock.acquire(self, *a, **k)
#     102 def acquire(self, *a, **k):
#     103     for lock in self.locks:
# --> 104         lock.acquire(*a, **k)
#
# KeyboardInterrupt:

# %%
print(f"Loading {BASE_MODEL_NAME} from local cache...")

word_embedding_model = models.Transformer(BASE_MODEL_NAME)

pooling_model = models.Pooling(
    word_embedding_model.get_word_embedding_dimension(), 
    pooling_mode_mean_tokens=True
)

if device == 'mps':
    print("Moving model to Apple Neural Engine (MPS)...")

model = SentenceTransformer(
    modules=[word_embedding_model, pooling_model], 
    device=device
)

print(f"✅ Model successfully loaded on device: {model.device}")
# Out:
# Initializing base model: distilbert-base-uncased...
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Cancellation requested; stopping current tasks.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/huggingface_hub/file_download.py:626, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, _tqdm_bar)
#     624     progress.update(progress_bytes)
# --> 626 download_files(
#     627     xet_download_info,
#     628     endpoint=connection_info.endpoint,
#     629     token_info=(connection_info.access_token, connection_info.expiration_unix_epoch),
#     630     token_refresher=token_refresher,
#     631     progress_updater=[progress_updater],
#     632 )
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 print(f"Initializing base model: {BASE_MODEL_NAME}...")
# ----> 3 word_embedding_model = models.Transformer(BASE_MODEL_NAME)
#       5 pooling_model = models.Pooling(
#       6     word_embedding_model.get_word_embedding_dimension(), pooling_mode_mean_tokens=True
#       7 )
#       9 model = SentenceTransformer(
#      10     modules=[word_embedding_model, pooling_model], device=device
#      11 )
#
# File ~/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/sentence_transformers/models/Transformer.py:89, in Transformer.__init__(self, model_name_or_path, max_seq_length, model_args, tokenizer_args, config_args, cache_dir, do_lower_case, tokenizer_name_or_path, backend)
#      86     config_args = {}
#      88 config, is_peft_model = self._load_config(model_name_or_path, cache_dir, backend, config_args)
# ---> 89 self._load_model(model_name_or_path, config, cache_dir, backend, is_peft_model, **model_args)
#      91 # Get the signature of the auto_model's forward method to pass only the expected arguments from `features`,
#      92 # plus some common values like "input_ids", "attention_mask", etc.
#      93 model_forward_params = list(inspect.signature(self.auto_model.forward).parameters)
#
# File ~/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/sentence_transformers/models/Transformer.py:197, in Transformer._load_model(self, model_name_or_path, config, cache_dir, backend, is_peft_model, **model_args)
#     195         self._load_mt5_model(model_name_or_path, config, cache_dir, **model_args)
#     196     else:
# --> 197         self.auto_model = AutoModel.from_pretrained(
#     198             model_name_or_path, config=config, cache_dir=cache_dir, **model_args
#     199         )
#     200 elif backend == "onnx":
#     201     self.auto_model = load_onnx_model(
#     202         model_name_or_path=model_name_or_path,
#     203         config=config,
#     204         task_name="feature-extraction",
#     205         **model_args,
#     206     )
#
# File ~/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:604, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     602     if model_class.config_class == config.sub_configs.get("text_config", None):
#     603         config = config.get_text_config()
# --> 604     return model_class.from_pretrained(
#     605         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     606     )
#     607 raise ValueError(
#     608     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     609     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping)}."
#     610 )
#
# File ~/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:277, in restore_default_dtype.<locals>._wrapper(*args, **kwargs)
#     275 old_dtype = torch.get_default_dtype()
#     276 try:
# --> 277     return func(*args, **kwargs)
#     278 finally:
#     279     torch.set_default_dtype(old_dtype)
#
# File ~/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:4900, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4890 if (
#    4891     gguf_file
#    4892     and device_map is not None
#    4893     and ((isinstance(device_map, dict) and "disk" in device_map.values()) or "disk" in device_map)
#    4894 ):
#    4895     raise RuntimeError(
#    4896         "One or more modules is configured to be mapped to disk. Disk offload is not supported for models "
#    4897         "loaded from GGUF files."
#    4898     )
# -> 4900 checkpoint_files, sharded_metadata = _get_resolved_checkpoint_files(
#    4901     pretrained_model_name_or_path=pretrained_model_name_or_path,
#    4902     subfolder=subfolder,
#    4903     variant=variant,
#    4904     gguf_file=gguf_file,
#    4905     from_tf=from_tf,
#    4906     from_flax=from_flax,
#    4907     use_safetensors=use_safetensors,
#    4908     cache_dir=cache_dir,
#    4909     force_download=force_download,
#    4910     proxies=proxies,
#    4911     local_files_only=local_files_only,
#    4912     token=token,
#    4913     user_agent=user_agent,
#    4914     revision=revision,
#    4915     commit_hash=commit_hash,
#    4916     is_remote_code=cls._auto_class is not None,
#    4917     transformers_explicit_filename=transformers_explicit_filename,
#    4918 )
#    4920 is_sharded = sharded_metadata is not None
#    4921 is_quantized = hf_quantizer is not None
#
# File ~/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:1037, in _get_resolved_checkpoint_files(pretrained_model_name_or_path, subfolder, variant, gguf_file, from_tf, from_flax, use_safetensors, cache_dir, force_download, proxies, local_files_only, token, user_agent, revision, commit_hash, is_remote_code, transformers_explicit_filename)
#    1022 try:
#    1023     # Load from URL or cache if already cached
#    1024     cached_file_kwargs = {
#    1025         "cache_dir": cache_dir,
#    1026         "force_download": force_download,
#    (...)
#    1035         "_commit_hash": commit_hash,
#    1036     }
# -> 1037     resolved_archive_file = cached_file(pretrained_model_name_or_path, filename, **cached_file_kwargs)
#    1039     # Since we set _raise_exceptions_for_missing_entries=False, we don't get an exception but a None
#    1040     # result when internet is up, the repo and revision exist, but the file does not.
#    1041     if resolved_archive_file is None and filename == _add_variant(SAFE_WEIGHTS_NAME, variant):
#    1042         # Maybe the checkpoint is sharded, we try to grab the index name in this case.
#
# File ~/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/transformers/utils/hub.py:322, in cached_file(path_or_repo_id, filename, **kwargs)
#     264 def cached_file(
#     265     path_or_repo_id: Union[str, os.PathLike],
#     266     filename: str,
#     267     **kwargs,
#     268 ) -> Optional[str]:
#     269     """
#     270     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     271
#    (...)
#     320     ```
#     321     """
# --> 322     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     323     file = file[0] if file is not None else file
#     324     return file
#
# File ~/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/transformers/utils/hub.py:479, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     476 try:
#     477     if len(full_filenames) == 1:
#     478         # This is slightly better for only 1 file
# --> 479         hf_hub_download(
#     480             path_or_repo_id,
#     481             filenames[0],
#     482             subfolder=None if len(subfolder) == 0 else subfolder,
#     483             repo_type=repo_type,
#     484             revision=revision,
#     485             cache_dir=cache_dir,
#     486             user_agent=user_agent,
#     487             force_download=force_download,
#     488             proxies=proxies,
#     489             resume_download=resume_download,
#     490             token=token,
#     491             local_files_only=local_files_only,
#     492         )
#     493     else:
#     494         snapshot_download(
#     495             path_or_repo_id,
#     496             allow_patterns=full_filenames,
#    (...)
#     505             local_files_only=local_files_only,
#     506         )
#
# File ~/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/huggingface_hub/file_download.py:1007, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     987     return _hf_hub_download_to_local_dir(
#     988         # Destination
#     989         local_dir=local_dir,
#    (...)
#    1004         local_files_only=local_files_only,
#    1005     )
#    1006 else:
# -> 1007     return _hf_hub_download_to_cache_dir(
#    1008         # Destination
#    1009         cache_dir=cache_dir,
#    1010         # File info
#    1011         repo_id=repo_id,
#    1012         filename=filename,
#    1013         repo_type=repo_type,
#    1014         revision=revision,
#    1015         # HTTP info
#    1016         endpoint=endpoint,
#    1017         etag_timeout=etag_timeout,
#    1018         headers=hf_headers,
#    1019         proxies=proxies,
#    1020         token=token,
#    1021         # Additional options
#    1022         local_files_only=local_files_only,
#    1023         force_download=force_download,
#    1024     )
#
# File ~/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/huggingface_hub/file_download.py:1168, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1165 # Local file doesn't exist or etag isn't a match => retrieve file from remote (or cache)
#    1167 with WeakFileLock(lock_path):
# -> 1168     _download_to_tmp_and_move(
#    1169         incomplete_path=Path(blob_path + ".incomplete"),
#    1170         destination_path=Path(blob_path),
#    1171         url_to_download=url_to_download,
#    1172         proxies=proxies,
#    1173         headers=headers,
#    1174         expected_size=expected_size,
#    1175         filename=filename,
#    1176         force_download=force_download,
#    1177         etag=etag,
#    1178         xet_file_data=xet_file_data,
#    1179     )
#    1180     if not os.path.exists(pointer_path):
#    1181         _create_symlink(blob_path, pointer_path, new_blob=True)
#
# File ~/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/huggingface_hub/file_download.py:1720, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download, etag, xet_file_data)
#    1718 if xet_file_data is not None and is_xet_available():
#    1719     logger.debug("Xet Storage is enabled for this repo. Downloading file from Xet Storage..")
# -> 1720     xet_get(
#    1721         incomplete_path=incomplete_path,
#    1722         xet_file_data=xet_file_data,
#    1723         headers=headers,
#    1724         expected_size=expected_size,
#    1725         displayed_filename=filename,
#    1726     )
#    1727 else:
#    1728     if xet_file_data is not None and not constants.HF_HUB_DISABLE_XET:
#
# File ~/GitHub/ML-Portfolio/.venv/lib/python3.10/site-packages/huggingface_hub/file_download.py:626, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, _tqdm_bar)
#     623 def progress_updater(progress_bytes: float):
#     624     progress.update(progress_bytes)
# --> 626 download_files(
#     627     xet_download_info,
#     628     endpoint=connection_info.endpoint,
#     629     token_info=(connection_info.access_token, connection_info.expiration_unix_epoch),
#     630     token_refresher=token_refresher,
#     631     progress_updater=[progress_updater],
#     632 )
#
# KeyboardInterrupt:

# %%
train_loss = losses.MultipleNegativesRankingLoss(model)

warmup_steps = int(len(train_dataloader) * NUM_EPOCHS * 0.1)

print("Starting training...")

model.fit(
    train_objectives=[(train_dataloader, train_loss)],
    epochs=NUM_EPOCHS,
    warmup_steps=warmup_steps,
    show_progress_bar=True,
)

model.save(OUTPUT_PATH)
print(f"Training finished! Model saved to {OUTPUT_PATH}")

# %%
print("Loading trained model for inference...")
trained_model = SentenceTransformer(OUTPUT_PATH)

test_query = "How do I make coffee?"
test_docs = [
    "To brew coffee, grind beans and use hot water in a french press.",  # Relevant
    "The capital of France is Paris.",  # Irrelevant
    "Python is a programming language.",  # Irrelevant
    "Boiling water is essential for extracting flavor from coffee beans.",  # Relevant
]

query_emb = trained_model.encode(test_query)
doc_embs = trained_model.encode(test_docs)

scores = util.cos_sim(query_emb, doc_embs)[0]

print(f"\nQuery: {test_query}")
print("-" * 50)
results = list(zip(test_docs, scores))
for doc, score in sorted(results, key=lambda x: x[1], reverse=True):
    print(f"Score: {score:.4f} | {doc}")
